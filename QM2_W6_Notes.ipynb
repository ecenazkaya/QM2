# %% [markdown]
# <a href="https://colab.research.google.com/github/ecenazkaya/QM2/blob/main/QM2_W6_Notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# W6 NOTES
#
# For the rest of this course, we'll be working with data from the U.S. Census Current Population Survey (CPS).
#
# We will be following on from Workshop 5. We visually explored differences in the income levels between different groups of people in the US census. Now, we are going to conduct hypothesis testing to see if those differences are statistically significant.

# %%
#This tells python to draw the graphs "inline" - in the notebook
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics
import seaborn as sns

import pylab
import pandas as pd
import numpy as np
# make the plots (graphs) a little wider by default
pylab.rcParams['figure.figsize'] = (10., 8.)
sns.set(font_scale=1.5)
sns.set_style("white")

# %%
df=pd.read_csv('https://storage.googleapis.com/qm2/wk7/cps.csv')
df['race']=df['race'].astype('category')
df['income']=df['incwage']/1000
df=df[df['income']<200]
df=df[df['year']==2013] # filter the dataframe to only contain 2013 data
df.head()
# Out:
#     year  state  age  sex race   sch   ind  union  incwage  realhrwage  \
# 20  2013     50   62    1    1  14.0  8090    1.0  57000.0   23.889143
# 32  2013     39   59    1    1  13.0  9590    0.0  62000.0   29.726475
# 34  2013     44   44    1    3  12.0  7290    0.0  45000.0   20.745834
# 36  2013     12   41    1    1  12.0  7070    1.0  28000.0   12.293828
# 37  2013     33   35    1    1  12.0   770    0.0  42500.0   20.377020
#
#                                occupation  income
# 20                                      .    57.0
# 32  Consruction, Extraction, Installation    62.0
# 34                                      .    45.0
# 36                               Managers    28.0
# 37    Transportation and materials moving    42.5

# %% [markdown]
# This is once again the U.S. census data from Week 5. As a reminder, our dataframe has 10 columns:
#
# 1. *year*: Survey year
# 2. *age*: the person's age
# 3. *sex*: the person's sex
#     * 1=male
#     * 2=female
# 4. *race*: the person's race
#     * White non hispanic=1
#     * Black non hispanic=2
#     * Hispanic=3
#     * Other non hispanic=4)
# 5. *sch*: Educational attainment
#     * None = 0,
#     * Grades 1-12 = 1-12
#     * Some University = 13,
#     * Associate's degree = 14,
#     * BA = 16
#     * Advanced Degree = 18
# 6. *union*: Union membership
#     * N/A = 0,
#     * No union coverage = 1,
#     * Member of labor union=2,
#     * Covered by union but not a member=3
# 7. *incwage*: Wage and salary income
# 8. *realhrwage*: Real Hourly Wage
# 9. *occupation*: Occupation
# 10. *ind*: [industry code](https://www.census.gov/naics/?58967?yearbck=2002)

# %% [markdown]
# **Confidence Intervals:**
#
# So far in this workshop, we've had the luxury of being able to draw many random samples and plot the distributions of their sample means to infer the population mean. The Central Limit Theorem lets us assume that these sample means are normally distributed, and consequently that there is a 95.45% chance that the **population mean** within two standard errors of the **sample mean**. This allows us to make inferences on the basis of *a single sample*. The standard error is the
#
# ### Sample Standard Deviation
# $$\huge s = \sqrt{\frac{1}{n-1} \sum_{i=1}^n (x_i - \overline{x})^2}$$
#
# ### Standard Error
# $$\huge se = \frac{s}{\sqrt{n}}$$
#
# Given a large enough sample $x$, we can build a 95% confidence interval as follows:
#
# $$ \huge 95\% CI = \overline{x} \pm (1.96 \times se)$$
#
# Let's draw a sample of 1000 random individuals from our data, and compute a 95% confidence interval to estimate the population mean for income. We'll begin by creating a swarmplot to get a sense of how the data are distributed.

# %%
sample=df.sample(1000) # draw a random sample of 1000 observations from the dataframe
sns.swarmplot(data = sample, y='income') # plot a swarmplot of income
plt.title('Income Distribution') # add a title
# Out:
# Text(0.5, 1.0, 'Income Distribution')

# %% [markdown]
# Now let's set about calculating the 95% confidence interval and plotting it on our swarmplot. Luckily, the components we need to this are easy to calculate. We just need the mean, standard deviation, and number of observations. All of these are provided by the .describe() function, which calculates summary statistics for a sample.

# %%
desc=sample['income'].describe() # calculate descriptive statistics for the sample
print(desc) # print the descriptive statistics
# Out:
# count    1000.000000
# mean       48.748067
# std        33.255107
# min         0.500000
# 25%        25.000000
# 50%        40.000000
# 75%        67.025000
# max       198.000000
# Name: income, dtype: float64

# %% [markdown]
# From the set of descriptive statistics, we can pull out the relevant components, calculate the standard error, and create a 95% confidence interval as follows:

# %%
mean=desc['mean'] # set the mean equal to a variable called "mean"
std=desc['std'] # set the standard deviation equal to a variable called "std"
n=desc['count'] # set the sample size equal to a variable called "n"
se=std/np.sqrt(n) # calculate the standard error of the mean

print('The mean is', round(mean, 2), 'with a standard error of', round(se, 2)) # print the mean and standard error

upper_ci = mean+se*1.96 # calculate the upper confidence interval
lower_ci = mean-se*1.96 # calculate the lower confidence interval

print('The 95% confidence interval is', round(lower_ci, 2), 'to', round(upper_ci, 2)) # print the confidence interval
# Out:
# The mean is 48.75 with a standard error of 1.05
# The 95% confidence interval is 46.69 to 50.81

# %% [markdown]
# Finally, let's plot these bounds on our swarmplot to graphically show this range. We can now claim that based on our sample, there is a 95% chance that the true population mean of income (shown in red) lies within this range.

# %%
sns.swarmplot(data = sample, y='income',alpha=0.5) # plot a swarmplot of income
plt.axhline(df['income'].mean(), color='red', linestyle='solid', linewidth=3, label='Population Mean') # add a horizontal line at the mean
plt.axhline(upper_ci, color='black', linestyle='dashed', linewidth=3) # add a dashed black line at the upper confidence interval
plt.axhline(lower_ci, color='black', linestyle='dashed', linewidth=3) # add a dashed black line at the lower confidence interval

plt.title('Income Distribution, 95% Confidence Interval') # add a title
# Out:
# Text(0.5, 1.0, 'Income Distribution, 95% Confidence Interval')

# %% [markdown]
# **Hypothesis Testing:**
#
# If we create a boxplot of income disaggregated by sex using our sample, we can observe that men seem to earn more than women:

# %%
sns.boxplot(data=sample , x='sex', y='income').set_xticklabels(['Men','Women']) # make a box plot of income by sex
# Out:
# <ipython-input-7-ff57182b0dfb>:1: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   sns.boxplot(data=sample , x='sex', y='income').set_xticklabels(['Men','Women']) # make a box plot of income by sex
# [Text(0, 0, 'Men'), Text(1, 0, 'Women')]

# %% [markdown]
# But is this difference statistically significant? It could just be due to sampling error, random chance. Hypothesis testing provides a framework through which we can formally evaluate the likelihood of encountering an effect as extreme (in this case, the the difference between the mean incomes between both groups) as the one we observe in our data. There are four main steps in hypothesis testing:
#
# - State the hypotheses. H0 states that there is no difference between the two population means.
# - Select an  𝛼  level (e.g. 95% confidence), and select a corresponding critical value (1.96 for large samples)
# - Compute the test statistic.
# - Make a decision; if the test statistic exceeds the critical value, we reject the null hypothesis.
#
# Steps 1, 2, and 4 remain fairly constant, but step 3 can vary quite a bit, as there are many different statistical tests that fall under the umbrella of hypothesis testing. In today's workshop we'll be using the Student's T-Test.

# %% [markdown]
# **State the hypotheses:**
#
# **The Null Hypothesis:**
#
# 𝐻0  : There is no difference in the mean income between men and women
#
# 𝐻0  :  𝑥⎯⎯⎯𝑚𝑒𝑛=𝑥⎯⎯⎯𝑤𝑜𝑚𝑒𝑛
#
# **The Alternative Hypothesis:**
#
# 𝐻𝑎  : There is a difference in the mean income between men and women
#
# 𝐻𝑎  :  𝑥⎯⎯⎯𝑚𝑒𝑛≠𝑥⎯⎯⎯𝑤𝑜𝑚𝑒𝑛

# %% [markdown]
# **Select an  𝛼  level:**
#
# Locate the critical region; the critical values for the t statistic are obtained using degrees of freedom ( 𝑑𝑓=𝑛−2 ). Given that we have 1000 observations,  𝑑𝑓=998 . If  𝑑𝑓>1000 , you can simply memorize the following critical values:
#
# - At the 95% confidence level, the critical value is 1.96
# - At the 99% confidence level, the critical value is 2.58
#
# If our test statistic exceeds either of these values, we can reject the null hypothesis with the according level of confidence. The function below creates a plot which provides a visual reference for these values, but isn't really necessary for the process of hypothesis testing. The function accepts one argument test_statistic, which it will use to plot a vertical red line. If the red line falls within the dotted lines, we fail to reject the null hypothesis at the corresponding confidence level. If it's outside of these bounds, we reject the null hypothesis.

# %%
def plot_z(test_statistic):
    mu, se= 0, 1 # create two variables, a mean "mu" equal to zero, and standard deviation "se" equal to 1
    x = np.linspace(mu - 3*se, mu + 3*se, 100) # create a range of values from -3 to 3 standard deviations

    plt.plot(x, norm.pdf(x, mu, se)) # plot the normal distribution
    plt.axvline(mu-se*1.96, color='blue', linestyle='dashed', linewidth=1.5,label='µ ± 1.96σ (95% confidence)') # plot a vertical line at the mean plus 2 standard deviations
    plt.axvline(mu+se*1.96, color='blue', linestyle='dashed', linewidth=1.5)  # plot a vertical line at the mean minus 2 standard deviations
    plt.axvline(mu-se*2.58, color='green', linestyle='dashed', linewidth=1.5,label='µ ± 2.58σ (99% confidence)') # plot a vertical line at the mean plus 2 standard deviations
    plt.axvline(mu+se*2.58, color='green', linestyle='dashed', linewidth=1.5)  # plot a vertical line at the mean minus 2 standard deviations

    plt.axvline(test_statistic, color='red', linestyle='solid', linewidth=1.5,label='Test Statistic') # plot a vertical line at the test statistic


    plt.ylim(0,0.4)
    plt.legend()
    plt.title('Z Distribution') # add a title
    plt.show()

plot_z(-2.3)

# %% [markdown]
# **Calculate the test statistic (The Student's T-Test):**
#
# The Student's T-Test is an *independent-measures design* which is used in situations where a researcher has no prior knowledge about either of the two populations (or treatments) being compared.  In particular, the population means and standard deviations are all unknown. Because the population variances are not known, these values must be estimated from the sample data.
#
# The purpose of a T-test is to determine whether the sample mean difference indicates a real mean difference between the two populations or whether the obtained difference is simply the result of sampling error. Given two groups, $x_1$ and $x_2$, the $t$ statistic is calculated as:
#
# $$ \Huge t = {\frac{\overline{x_1}-\overline{x_2}} {\sqrt{\frac{s^2_1}{n_1} + \frac{s^2_2}{n_2}}}} $$
#
# Where:
#
# - $\overline{x}$: Sample Mean
# - $s^2$: Sample Standard Deviation
# - $n$: Number of observations
#
# We've already seen how to calculate each of these components when we made the 95% confidence interval above using the `.describe()` function. To calculate the t-statistic, we just have to plug these values into the formula above and do some basic arithmetic. I've put together a function that does this below, which accepts two main arguments, `group1` and `group2`. For each group it calculates descriptive statistics, and uses these values to calculate the t-statistic. It also has an optional argument `plot`, which when set to `True` will plot a 95% confidence interval for each group. It defaults to `False`, meaning that it won't generate the plot.

# %%
def manual_ttest(group1, group2, plot=False): # define a function called "manual_ttest" that takes two groups and a boolean value for whether or not to plot the results as arguments

    desc1, desc2=group1.describe(), group2.describe() # get descriptive statistics for both samples

    n1,std1,mean1 = desc1['count'], desc1['std'] ,desc1['mean'] # get the sample size, standard deviation, and mean of the first sample
    n2,std2,mean2 = desc2['count'], desc2['std'] ,desc2['mean'] # get the sample size, standard deviation, and mean of the second sample

    # calculate standard errors
    se1, se2 = std1**2/n1, std2**2/n2 # '**2' is the same as squaring the number

    # standard error on the difference between the samples
    sed = np.sqrt(se1 + se2)

    # calculate the t statistic
    t_stat = (mean1 - mean2) / sed

    # print the results
    print("Group 1: n=%.0f, mean=%.3f, std=%.3f" % (n1,mean1,std1))
    print("Group 2: n=%.0f, mean=%.3f, std=%.3f" % (n2,mean2,std2))
    print('The t-statistic is %.3f' % t_stat) # print the t-statistic

    if plot==True: # if the plot argument is set to True, plot the results
        groups=pd.DataFrame() # create an empty dataframe
        i=1 # create a counter variable called "i" and set it equal to 1

        for group in [group1, group2]: # loop through each group in the list of groups
            plot_df=pd.DataFrame({'Values': group,'Group':i}) # create a dataframe with the values of the group and a column called "Group" that contains the group number
            groups=groups.append(plot_df) # append the dataframe to the list of dataframes
            i+=1 # increase the counter by 1

        sns.pointplot(data=groups , x='Group', y='Values',errorbar=('ci', 95), color='black', join=False, capsize=.8) # plot the means of the groups with a 95% confidence interval
        plt.title('Comparison of Group Means with 95% Confidence Intervals') # add a title

    return t_stat # return the t-statistic

# %% [markdown]
# Having defined the function, we can now call it to calculate a t-test for the difference in income between men and women

# %%
men=sample[sample['sex']==1] # filter the sample to only include men
women=sample[sample['sex']==2] # filter the sample to only include women

t = manual_ttest(men['income'],women['income']) # run the t-test function and store the t-statistic in a variable called "t"
# Out:
# Group 1: n=530, mean=56.261, std=35.183
# Group 2: n=470, mean=40.276, std=28.700
# The t-statistic is 7.906

# %% [markdown]
# **Make a decision: **
#
# If the t statistic indicates that the obtained difference between sample means (numerator) is substantially greater than the difference expected by chance (denominator), we reject H0 and conclude that there is a real mean difference between the two populations or treatments. Let plot the T-statistic from our test against the critical values:

# %%
plot_z(t) # plot the test statistic on the z distribution

# %% [markdown]
# Based on the plot above, can we reject the null hypothesis that there is no difference in mean income between men and women?
#
# The red line is outside the bounds which means that we reject the null hypothesis. There is a difference in the mean income between men and women.

# %% [markdown]
# **Exercise:**
#
# - From the main dataframe df, draw a sample of 500 white men. Using t-tests, investigate whether there are statistically significant discrepancies in pay between white men and other groups (note: it would be best to sample 500 people in each of those groups as well). Between what groups does there exist the most significant pay gap?

# %%
white_men = df[(df['race'] == 1) & (df['sex'] == 1)].sample(500)

# Sample 500 white women
white_women = df[(df['race'] == 1) & (df['sex'] == 2)].sample(500)

# Sample 500 Black men
black_women = df[(df['race'] == 2) & (df['sex'] == 2)].sample(500)
# and so on for other groups...

# Perform t-test between white men and white women
t_stat_ww = manual_ttest(white_men['income'], white_women['income'])

# Perform t-test between white men and Black men
t_stat_bm = manual_ttest(white_men['income'], black_women['income'])
# and so on for other groups...

# Create a list to store the t-statistics and group names
t_stats = [t_stat_ww, t_stat_bm] # Add other t-statistics here
groups = ['white_women', 'black_women'] # Add other group names here


# Assuming you stored all t-statistics in a list called t_stats
max_t_stat = max(t_stats)  # Find the largest t-statistic (absolute value)
group_with_max_gap = groups[t_stats.index(max_t_stat)] # Get the group corresponding to the largest t-statistic
# here groups would be a list containing names of the groups
# Out:
# Group 1: n=500, mean=59.974, std=34.694
# Group 2: n=500, mean=42.032, std=30.712
# The t-statistic is 8.659
# Group 1: n=500, mean=59.974, std=34.694
# Group 2: n=500, mean=37.540, std=24.940
# The t-statistic is 11.740

# %% [markdown]
# The most significant pay gap exists between white men and black men because they have the largest t-statistic.

# %% [markdown]
# T-test 1: White Men vs. White Women
#
# Group 1: White men (n=500, mean income = $59,974, std = $$59,974, std = $34,694)
# Group 2: White women (n=500, mean income = $42,032, std = $$42,032, std = $30,712)
# T-statistic: 8.659
#
# Interpretation:
#
# This t-test compares the income of white men to white women. The t-statistic of 8.659 is quite large, indicating a substantial difference between the mean incomes of the two groups. Given a typical critical value of around 1.96 for a 95% confidence level, this t-statistic far exceeds the critical value.
#
# T-test 2: White Men vs. Black Women
#
# Group 1: White men (n=500, mean income = $59,974, std = $$59,974, std = $34,694)
# Group 2: Black women (n=500, mean income = $37,540, std = $$37,540, std = $24,940)
# T-statistic: 11.740
#
# Interpretation:
#
# This t-test compares the income of white men to Black women. The t-statistic of 11.740 is even larger than in the previous test, indicating a more substantial difference between the mean incomes of these two groups. Again, this t-statistic is much greater than the typical critical value for a 95% confidence level.

# %% [markdown]
# - Some of this variation may be due to occupation. Compare income disparities between men and women within different occupations. Which occupation has the largest pay gap? which has the smallest?

# %%
occupation_groups = df.groupby('occupation')

# 2. Calculate Statistics for Each Occupation
occupation_stats = occupation_groups.apply(lambda x: pd.Series({
    'male_mean_income': x[x['sex'] == 1]['income'].mean(),
    'female_mean_income': x[x['sex'] == 2]['income'].mean(),
    'male_count': x[x['sex'] == 1]['income'].count(),
    'female_count': x[x['sex'] == 2]['income'].count()
}))

# 3. Calculate Pay Gap
occupation_stats['pay_gap'] = occupation_stats['male_mean_income'] - occupation_stats['female_mean_income']

# 4. Identify Largest and Smallest Pay Gaps
largest_gap_occupation = occupation_stats.sort_values('pay_gap', ascending=False).index[0]
smallest_gap_occupation = occupation_stats.sort_values('pay_gap', ascending=True).index[0]

print(f"Occupation with largest pay gap: {largest_gap_occupation}")
print(f"Occupation with smallest pay gap: {smallest_gap_occupation}")

# Optional: Print the entire occupation_stats DataFrame for detailed analysis
print(occupation_stats)
# Out:
# Occupation with largest pay gap: financial Operators
# Occupation with smallest pay gap: Community and Social Workers
#                                         male_mean_income  female_mean_income  \
# occupation
# .                                              51.279018           35.514843
# Business Operators                             68.818568           54.502821
# Community and Social Workers                   43.968493           40.584923
# Computer and Math Technicians                  79.269207           68.671277
# Consruction, Extraction, Installation          46.135590           40.965023
# Farming, Fishing & Forestry                    28.874026           18.545805
# Lawyers, Judges,Physicans and dentists        103.427909           97.827203
# Managers                                       80.191172           63.145124
# Office and Admin Support                       43.712950           33.643429
# Production                                     41.949286           26.913704
# Protective Service adj_occupations             59.264229           43.851902
# Transportation and materials moving            39.788753           24.597715
# financial Operators                            70.211597           52.156777
#
#                                         male_count  female_count    pay_gap
# occupation
# .                                           8122.0       13364.0  15.764175
# Business Operators                           537.0         776.0  14.315747
# Community and Social Workers                 361.0         697.0   3.383571
# Computer and Math Technicians               1247.0         530.0  10.597930
# Consruction, Extraction, Installation       4320.0         131.0   5.170567
# Farming, Fishing & Forestry                  270.0          82.0  10.328221
# Lawyers, Judges,Physicans and dentists       296.0         231.0   5.600705
# Managers                                    3052.0        2447.0  17.046049
# Office and Admin Support                    1734.0        5486.0  10.069521
# Production                                  2449.0        1008.0  15.035582
# Protective Service adj_occupations          1051.0         276.0  15.412327
# Transportation and materials moving         2635.0         541.0  15.191037
# financial Operators                          477.0         803.0  18.054820
# <ipython-input-16-f09e1bfc8bd0>:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   occupation_stats = occupation_groups.apply(lambda x: pd.Series({

# %% [markdown]
# Financial operators have the largest pay gap and community and social workers have the smallest.

# %% [markdown]
# - Research suggests that within occupational groups, collective bargaining through union membership reduces pay gaps. Read the abstract of this article, and try to replicate the analysis using our dataset.

# %%
# Group data by occupation and union status (1: No union, 2: Union member)
grouped_data = df.groupby(['occupation', 'union'])['income'].mean().reset_index()

# Pivot the table for easier comparison between union and non-union wages
pivot_data = grouped_data.pivot(index='occupation', columns='union', values='income')

# Get the actual column names after pivoting
# This will give you a list of the current column names
actual_column_names = pivot_data.columns.tolist()

# Print to see the names:
print(actual_column_names)

# Example: if you see [0, 1, 2, 3] as output you need to name all 4 union statuses.
# Change to match the actual column names or reduce pivot table to have fewer columns
# Replace with your desired names, ensuring the correct number of columns:
pivot_data.columns = [0, 1, 2, 3]  #  assuming your pivot data columns are indeed [0,1,2,3]
# Example: pivot_data.columns = ['non_union_wage', 'union_wage', 'covered_not_member_wage', 'another_union_status'] # Replace 'another_union_status'

# Select only the desired columns for comparison
pivot_data = pivot_data[[0, 1]]  # Assuming 0 and 1 are your desired union status indicators for non-union and union

# Rename for clarity
pivot_data = pivot_data.rename(columns={0: "non_union_wage", 1: "union_wage"})

# Calculate the pay gap within each occupation for union vs. non-union
pivot_data['pay_gap_diff'] = pivot_data['union_wage'] - pivot_data['non_union_wage']

# Examine 'pay_gap_diff': Positive values suggest unions reduce the pay gap
# Sort to find occupations with the largest impact
print(pivot_data.sort_values('pay_gap_diff', ascending=False))
# Out:
# [0.0, 1.0, 2.0, 3.0]
#                                         non_union_wage  union_wage  \
# occupation
# Computer and Math Technicians                75.520956   79.148097
# financial Operators                          58.391156   61.059980
# Managers                                     72.488968   73.106233
# Production                                   37.214564   37.299732
# .                                            41.274927   41.176799
# Farming, Fishing & Forestry                  26.038203   25.935356
# Community and Social Workers                 41.284233   40.519677
# Business Operators                           60.520337   59.059629
# Office and Admin Support                     36.182382   34.005865
# Consruction, Extraction, Installation        45.825858   43.302289
# Transportation and materials moving          37.236826   32.992682
# Lawyers, Judges,Physicans and dentists      102.499261   93.721662
# Protective Service adj_occupations           56.718805   45.140790
#
#                                         pay_gap_diff
# occupation
# Computer and Math Technicians               3.627141
# financial Operators                         2.668824
# Managers                                    0.617265
# Production                                  0.085168
# .                                          -0.098128
# Farming, Fishing & Forestry                -0.102848
# Community and Social Workers               -0.764556
# Business Operators                         -1.460708
# Office and Admin Support                   -2.176517
# Consruction, Extraction, Installation      -2.523570
# Transportation and materials moving        -4.244144
# Lawyers, Judges,Physicans and dentists     -8.777599
# Protective Service adj_occupations        -11.578016

# %% [markdown]
# **Assessed Question:**
#
# When Elon musk bought Twitter, he promisted to restore "free speech" to the platform. He heralded this new era with a tweet on 28/10/2022, which read "the bird is freed". A tidal wave of hate speech ensued instead.
#
# Using twitter's API, I downloaded tweets containing a racial slur. Using the groupby function and regex, I counted the number of mentions of this word per hour on the platform for about a month before the takeover, and a few days thereafter. I've saved these counts (but not the tweets themselves) as a csv file called "elon_tweets.csv".
#
# The code below downloads this csv file, and plots the number of slur-containing tweets over time.

# %%
import datetime
from matplotlib.pyplot import figure
import matplotlib.dates as mdates

tweets=pd.read_csv('https://storage.googleapis.com/qm2/wk7/elon_twitter.csv') # read in the data
figure(figsize=(10, 4), dpi=200)
tweets['hour']=pd.to_datetime(tweets['hour'])

tweet=datetime.datetime(2022, 10, 28)

pre_mean=tweets[tweets['hour']<tweet]['count'].mean()
post_mean=tweets[tweets['hour']>tweet]['count'].mean()
pct_change= int(((post_mean-pre_mean)/pre_mean)*100)

plt.ylabel('Hourly Slur Tweets')

plt.plot_date(tweets['hour'], tweets['count'], 'b', color='red')
plt.axvline(tweet, color='black', linestyle='dashed', label='"the bird is freed"')
plt.legend()
plt.title('Elon Musk tweets "The bird is freed"; Tweets containing racial slurs increase {}%'.format(pct_change))
plt.gca().xaxis.set_major_locator(mdates.DayLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d/%m'))
# Out:
# <ipython-input-19-5849b9dae105>:7: UserWarning: Parsing dates in %d/%m/%Y %HH format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   tweets['hour']=pd.to_datetime(tweets['hour'])
# <ipython-input-19-5849b9dae105>:17: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b" (-> color=(0.2980392156862745, 0.4470588235294118, 0.6901960784313725, 1)). The keyword argument will take precedence.
#   plt.plot_date(tweets['hour'], tweets['count'], 'b', color='red')

# %% [markdown]
# This plot definitely shows an uptick in the number of tweets containing a racial slur following Musk's tweet. But is this increase statistically significant?
#
# Question: Using a t-test and the full hypothesis testing procedure, investigate wheter there was a statistically significant increase in hate speech following Elon Musk's tweet. Make note of the T statistic and the P value.

# %% [markdown]
# 1) State the hypotheses
#
# **The Null Hypothesis:**
#
# 𝐻0  : There is no difference in the average number of hate speech tweets per hour before and after Elon Musk's tweet.
#
# **The Alternative Hypothesis:**
#
# 𝐻𝑎  : There is a difference in the average number of hate speech tweets per hour before and after Elon Musk's tweet.
#
# 2) Select an  $\alpha$ level
#
# - At the 95% confidence level, the critical value is 1.96
# - At the 99% confidence level, the critical value is 2.58
#
# If our test statistic exceeds either of these values, we can reject the null hypothesis with the according level of confidence.
#
# If the red line falls within the dotted lines, we fail to reject the null hypothesis at the corresponding confidence level. If it's outside of these bounds, we reject the null hypothesis.

# %% [markdown]
# 3) Find the t-statistic:

# %%
def manual_ttest(group1, group2, plot=False): # define a function called "manual_ttest" that takes two groups and a boolean value for whether or not to plot the results as arguments

    desc1, desc2=group1.describe(), group2.describe() # get descriptive statistics for both samples

    n1,std1,mean1 = desc1['count'], desc1['std'] ,desc1['mean'] # get the sample size, standard deviation, and mean of the first sample
    n2,std2,mean2 = desc2['count'], desc2['std'] ,desc2['mean'] # get the sample size, standard deviation, and mean of the second sample

    # calculate standard errors
    se1, se2 = std1**2/n1, std2**2/n2 # '**2' is the same as squaring the number

    # standard error on the difference between the samples
    sed = np.sqrt(se1 + se2)

    # calculate the t statistic
    t_stat = (mean1 - mean2) / sed

    # print the results
    print("Group 1: n=%.0f, mean=%.3f, std=%.3f" % (n1,mean1,std1))
    print("Group 2: n=%.0f, mean=%.3f, std=%.3f" % (n2,mean2,std2))
    print('The t-statistic is %.3f' % t_stat) # print the t-statistic

    if plot==True: # if the plot argument is set to True, plot the results
        groups=pd.DataFrame() # create an empty dataframe
        i=1 # create a counter variable called "i" and set it equal to 1

        for group in [group1, group2]: # loop through each group in the list of groups
            plot_df=pd.DataFrame({'Values': group,'Group':i}) # create a dataframe with the values of the group and a column called "Group" that contains the group number
            groups=groups.append(plot_df) # append the dataframe to the list of dataframes
            i+=1 # increase the counter by 1

        sns.pointplot(data=groups , x='Group', y='Values',errorbar=('ci', 95), color='black', join=False, capsize=.8) # plot the means of the groups with a 95% confidence interval
        plt.title('Comparison of Group Means with 95% Confidence Intervals') # add a title

    return t_stat # return the t-statistic

# %%
# Create two groups: before and after the tweet
before = tweets[tweets['hour'] < tweet]['count']
after = tweets[tweets['hour'] > tweet]['count']

# Perform the t-test
t_statistic = manual_ttest(before, after) # Pass the variables, not strings
# Out:
# Group 1: n=192, mean=41.339, std=18.212
# Group 2: n=47, mean=481.872, std=225.681
# The t-statistic is -13.372

# %%
plot_z(t_statistic)

# %% [markdown]
# 4) Making a decision:
#
# The red line falls outside of the dotted lines which means that we're rejecting the null hypothesis. There is a difference in the average number of hate speech tweets per hour before and after Elon Musk's tweet.
